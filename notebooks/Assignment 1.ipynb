# %% [markdown]
# # ASSIGNMENT 1 _(due Thursday, Sept 1st 11:59 PM)_
#
# <hr />
#
# # Name: _Insert your Name here_
#
# # Furman ID: _Insert your Furman student ID here_
#
# <hr />
#
# **Instructions**: _You are only allowed to use concepts convered in class. Mathematical and boolean operators should suffice for the problems below. Using any built-in python function calls other than `print` is strictly forbidden._
#
# _For submission,_
#
# _1. Put this jupyter notebook file in a folder._
#
# _2. Compress the folder._
#
# _3. Rename the folder your Furman ID_
#
# _4. Submit on Moodle under Assignment 1_
#
# <hr />

# %% [markdown]
# # 1. Compute Euclidean Distance
#
# Given two points $a$ and $b$, compute the Euclidean distance between them in Python.
#
# $a = (x_1, y_1)$ \
# $b = (x_2, y_2)$
#
# $ Distance_{Euclidean} = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$.
#
# Feel free to introduce new variables, as needed.
#
#
# **Example 1** \
# _Input(s) : $a=(-7, -4), b=(17, 6.5) $_ \
# `x1  = -7` \
# `y1 = -4` \
# `x2 = 17`\
# `y2 = 6.5`
#
# _Output(s): $ Distance_{Euclidean} = 26.196374 $_
#
# `distance = 26.196374`
#
# **Example 2** \
# _Input(s) : $a=(0, 10), b=(10, 0) $_ \
# `x1  = 0` \
# `y1 = 10` \
# `x2 = 10`\
# `y2 = 0`
#
# _Output(s): $ Distance_{Euclidean} = 14.142136 $_
#
# `distance = 14.142136`
#
# **Example 3** \
# _Input(s) : $a=(-12.34, -56.78), b=(-12.34, -56.78) $_ \
# `x1  = -12.34` \
# `y1 = -56.78` \
# `x2 = -12.34`\
# `y2 = -56.78`
#
# _Output(s): $ Distance_{Euclidean} = 0$_
#
# `distance = 0`

# %%
"""Inputs"""
# point a
x1 = 2
y1 = 3

# point b
x2 = 5
y2 = 7

"""Insert your line(s) of code here

Output(s):
---------
distance = 
"""

print("Inputs:\n x1:", x1, "y1:", y1, "\n x2:", x2, "y2:", y2, "\nOutput: ", distance)

# %% [markdown]
# # 2. Convert time from 12-hour format to 24-hour format
#
# Given three _**integers**_ `clock_12hrs_hrs`, `clock_12hrs_mins` and `pm` representing hours, minutes and AM/PM respectively in 12-hour time format, set integers `clock_24hrs_hrs` and `clock_24hrs_mins` to corresponding hours and minutes in 24-hour format time.
#
# `pm` $=0$ indicates input time is AM and `pm` $= 1$ means otherwise.
#
# Feel free to introduce new variables, as needed.
#
# _Constraints on input:_ \
# $0 \leq $ `pm` $ \leq 1$ \
# $1 \leq $ `clock_12hrs_hrs` $\leq 12$ \
# $ 0 \leq $ `clock_12hrs_mins` $ \lt 60 $
#
#
# **Example 1** \
# _Input : 7:30 PM_ \
# `clock_12hrs_hrs  = 7` \
# `clock_12hrs_mins = 30` \
# `pm = 1`
#
# _Outputs: 19:30_ \
# `clock_24hrs_hrs = 19`\
# `clock_24hrs_mins = 30`
#
# **Example 2** \
# _Input : 3:14 AM_ \
# `clock_12hrs_hrs  = 3` \
# `clock_12hrs_mins = 14`\
# `pm = 0`
#
# _Outputs: 3:14_ \
# `clock_24hrs_hrs = 3` \
# `clock_24hrs_mins = 14`
#
# **Example 3** \
# _Input : 12:00 PM_ \
# `clock_12hrs_hrs  = 12` \
# `clock_12hrs_mins = 0`\
# `pm = 1`
#
# _Outputs: 12:00_ \
# `clock_24hrs_hrs = 12` \
# `clock_24hrs_mins = 0`
#
# **Example 4** \
# _Input : 12:00 AM_ \
# `clock_12hrs_hrs  = 12` \
# `clock_12hrs_mins = 0`\
# `pm = 0`
#
# _Outputs: 0:00_ \
# `clock_24hrs_hrs = 0` \
# `clock_24hrs_mins = 0`
#
# <span style="color:red"><i><b>Make sure you test your code for inputs other than the ones provided above</b><i/></span>

# %%
""" Inputs """
clock_12hrs_hrs   = 12  # Test for values: 1, 2, 3,...., 10, 11, 12
clock_12hrs_mins  = 0 # Test for values: 0, 1, 2, 3,...., 57, 58, 59 
pm                = 0  # Test for values: 0, 1

"""Insert your lines of code here

Outputs
------- 
"""


clock_24hrs_hrs  = clock_12hrs_hrs % 12 + 12*pm
clock_24hrs_mins = clock_12hrs_mins

print("Inputs: ", clock_12hrs_hrs, clock_12hrs_mins, pm)
print("Outputs: ",  clock_24hrs_hrs, clock_24hrs_mins)
# Out:
# Inputs:  12 0 0
# Outputs:  0 0

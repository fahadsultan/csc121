# %% [markdown]
# ## <center>Due date: <i><b><span style="color:red">Thursday, September 15, 5:30 PM</span></b></i></center>
#
# <hr />
#
# ## Given an integer $n$ such that $0 \leq n \leq 9999$,
#
# ## **Q1. Reverse digits of $n$**
#
# * The output should be a variable `n_reverse` of type `int`
# * As with all and any variables of type `int`, there should and could be no leading zeros in the output (see examples 4 and 5 below).
#
# example 1:\
#     `n = 1234` \
#     `n_reverse = 4321`
#
# example 2: \
#     `n = 123`\
#     `n_reverse = 321`
#
# example 3: \
#     `n = 12`\
#     `n_reverse = 21`
#
# example 4:\
#     `n = 1230` \
#     `n_reverse = 321`
#
# example 5:\
#     `n = 1000` \
#     `n_reverse = 1`
#
# <hr/>
#
# ## **Q2. Check if $n$ is a _Palindrome_**
#
# * A palindromic number is a number (such as 16461) that remains the same when its digits are reversed.
# * The output variable should be named `n_palindrome` and of type `bool`
#
# _Example 1_ \
# Input:    `n = 1234` \
# Output:    `n_palindrome = False`
#
# _Example 2_ \
# Input:     `n = 121`\
# Output:    `n_palindrome = True`
#
# _Example 3_ \
# Input:      `n = 11`\
# Output:     `n_palindrome = True`
#
# _Example 4_ \
# Input:      `n = 12`\
# Output:     `n_palindrome = False`
#
# _Example 5_ \
# Input:      `n = 1`\
# Output:     `n_palindrome = True`
#
# <hr/>
#
# ## **Q3. Sum the digits of the $n$**
# * The output variable should be named `n_sum` and of type `int`
#
# _Example 1_ \
# Input:     `n = 1234` \
# Output:    `n_sum = 10` (1+2+3+4 = 10)
#
# _Example 2_ \
# Input:     `n = 121`\
# Output:    `n_sum = 4` (1+2+1 = 4)
#
# _Example 3_ \
# Input:     `n = 10`\
# Output:    `n_sum = 1` (1+0 = 1)
#
# _Example 4_ \
# Input:     `n = 1`\
# Output:    `n_sum = 1` (1 = 1)
#
# <hr />
#
# ## **Q4. Check if $n$ is a _Harshad number_**
# * A _Harshad number_ is a positive integer that is divisible by the sum of its digits.
# * The output variable should be named `n_harshad` and of type `bool`
#
# _Example 1_ \
# Input:      `n = 1711`\
# Output:     `n_harshad = False`
#
# _Example 2_ \
# Input:      `n = 198`\
# Output:     `n_harshad = True`
#
# _Example 3_ \
# Input:      `n = 171`\
# Output:     `n_harshad = True`
#
# _Example 4_ \
# Input:      `n = 10`\
# Output:     `n_harshad = False`
#
# _Example 5_ \
# Input:      `n = 2`\
# Output:     `n_harshad = True`
#
# <hr />
#
# ## Hint(s):
#
# * Break down $n$ into `ones`, `tens`, `hundreds`, `thousands`
#
#
# * $n = (1000*$ `thousands` $)~+~(100*$ `hundreds` $)~+~(10*$ `tens` $)~+~(1*$ `ones`$)$, for example, for $1853$:
#
#
#
#  ![base10](https://www.unm.edu/~tbeach/terms/images/base10.gif)
#
#
#  where `thousands` $=1$, `hundreds` $=8$,  `tens` $=5$ and `ones` $=3$

# %%
""" Input(s) """

# type: int; 0 <= n <= 9999
n = 1853

""" Output(s)  """

# type: int
n_reverse    

#type: bool
n_palindrome 

#type: int
n_sum        

#type: bool
n_harshad

# %%
number = 20

if (number % 4 == 0) and (number % 5 == 0):
    print("Multiple of both 4 and 5")
elif (number % 4 == 0):
    print("Multiple of 4")
elif number % 5 == 0:
    print("Multiple of 5")
else:
    print("Multiple of neither 4 nor 5")
# Out:
# Multiple of both 4 and 5
